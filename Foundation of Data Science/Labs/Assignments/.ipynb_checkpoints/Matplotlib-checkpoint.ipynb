# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.arange(10)
plt.plot(data)

# %%
fig = plt.figure()

# %%
ax1=fig.add_subplot(2,2,1)

# %%
ax1
# Out:
# <AxesSubplot:>

# %%
ax2=fig.add_subplot(2,2,2)

# %%
ax3=fig.add_subplot(2,2,3)

# %%
fig

# %%
ax4=fig.add_subplot(2,2,4)

# %%
fig

# %%
_=ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

# %%
_
# Out:
# (array([ 1.,  1.,  0.,  1.,  2.,  7.,  9., 13., 13.,  9., 10.,  9., 10.,
#          4.,  5.,  0.,  3.,  1.,  0.,  2.]),
#  array([-2.58120088, -2.31104478, -2.04088868, -1.77073258, -1.50057648,
#         -1.23042038, -0.96026428, -0.69010818, -0.41995208, -0.14979598,
#          0.12036012,  0.39051622,  0.66067232,  0.93082842,  1.20098452,
#          1.47114062,  1.74129672,  2.01145282,  2.28160892,  2.55176502,
#          2.82192112]),
#  <BarContainer object of 20 artists>)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
_
# Out:
# (array([ 1.,  1.,  0.,  1.,  2.,  7.,  9., 13., 13.,  9., 10.,  9., 10.,
#          4.,  5.,  0.,  3.,  1.,  0.,  2.]),
#  array([-2.58120088, -2.31104478, -2.04088868, -1.77073258, -1.50057648,
#         -1.23042038, -0.96026428, -0.69010818, -0.41995208, -0.14979598,
#          0.12036012,  0.39051622,  0.66067232,  0.93082842,  1.20098452,
#          1.47114062,  1.74129672,  2.01145282,  2.28160892,  2.55176502,
#          2.82192112]),
#  <BarContainer object of 20 artists>)

# %%
fig

# %%
_=ax4.scatter(np.arange(100), np.arange(100) + 10 * np.random.randn(100))

# %%
fig

# %%
ax4=fig.add_subplot(2,2,4)

# %%
fig

# %%
_=ax4.scatter(np.arange(100), np.arange(100) + 5 * np.random.randn(100))

# %%
fig

# %%
fig,axes = plt.subplots(2,3)

# %%
a=axes[0,1]

# %%
a
# Out:
# <AxesSubplot:>

# %%
fig

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
     for j in range(2):
             axes[i, j].hist(np.random.randn(500), bins=10, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.plot(np.random.randn(30).cumsum(), 'ko--')

# %%
 data = np.random.randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')

# %%
plt.legend(loc='best')
# Out:
# No handles with labels found to put in legend.
